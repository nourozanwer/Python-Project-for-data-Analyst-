# %%
import pandas as pd

# %%
df =pd.read_excel(r'C:\Python file short folder\compineslist.xlsx')
df
# Out:
#     Rank                      Name                    Industry  \
# 0      1                   Walmart                      Retail
# 1      2                    Amazon  Retail and cloud computing
# 2      3                ExxonMobil          Petroleum industry
# 3      4                     Apple        Electronics industry
# 4      5        UnitedHealth Group                  Healthcare
# ..   ...                       ...                         ...
# 95    96                  Best Buy                      Retail
# 96    97      Bristol-Myers Squibb     Pharmaceutical industry
# 97    98           United Airlines                     Airline
# 98    99  Thermo Fisher Scientific      Laboratory instruments
# 99   100                  Qualcomm                  Technology
#
#     Revenue (USD millions)  Revenue growth Employees             Headquarters
# 0                   611289           0.067   2100000    Bentonville, Arkansas
# ...

# %%
df.drop_duplicates()
# Out:
#     Rank                      Name                    Industry  \
# 0      1                   Walmart                      Retail
# 1      2                    Amazon  Retail and cloud computing
# 2      3                ExxonMobil          Petroleum industry
# 3      4                     Apple        Electronics industry
# 4      5        UnitedHealth Group                  Healthcare
# ..   ...                       ...                         ...
# 95    96                  Best Buy                      Retail
# 96    97      Bristol-Myers Squibb     Pharmaceutical industry
# 97    98           United Airlines                     Airline
# 98    99  Thermo Fisher Scientific      Laboratory instruments
# 99   100                  Qualcomm                  Technology
#
#     Revenue (USD millions)  Revenue growth Employees             Headquarters
# 0                   611289           0.067   2100000    Bentonville, Arkansas
# ...

# %%
#df =df.drop_dulpicates()

# %%
df = df.drop_duplicates()
df
# Out:
#     Rank                      Name                    Industry  \
# 0      1                   Walmart                      Retail
# 1      2                    Amazon  Retail and cloud computing
# 2      3                ExxonMobil          Petroleum industry
# 3      4                     Apple        Electronics industry
# 4      5        UnitedHealth Group                  Healthcare
# ..   ...                       ...                         ...
# 95    96                  Best Buy                      Retail
# 96    97      Bristol-Myers Squibb     Pharmaceutical industry
# 97    98           United Airlines                     Airline
# 98    99  Thermo Fisher Scientific      Laboratory instruments
# 99   100                  Qualcomm                  Technology
#
#     Revenue (USD millions)  Revenue growth Employees             Headquarters
# 0                   611289           0.067   2100000    Bentonville, Arkansas
# ...

# %%
#df = df.drop(columns = "Headquarters")
#df

# %%
df["Industry"].str.strip()
# Out:
# 0                         Retail
# 1     Retail and cloud computing
# 2             Petroleum industry
# 3           Electronics industry
# 4                     Healthcare
#                  ...
# 95                        Retail
# 96       Pharmaceutical industry
# 97                       Airline
# 98        Laboratory instruments
# 99                    Technology
# Name: Industry, Length: 100, dtype: object

# %%
df["Industry"].str.lstrip("...")
# Out:
# 0                         Retail
# 1     Retail and cloud computing
# 2             Petroleum industry
# 3           Electronics industry
# 4                     Healthcare
#                  ...
# 95                        Retail
# 96       Pharmaceutical industry
# 97                       Airline
# 98        Laboratory instruments
# 99                    Technology
# Name: Industry, Length: 100, dtype: object

# %%
df["Industry"].str.lstrip(["/","..."])
# Out:
# 0    NaN
# 1    NaN
# 2    NaN
# 3    NaN
# 4    NaN
#       ..
# 95   NaN
# 96   NaN
# 97   NaN
# 98   NaN
# 99   NaN
# Name: Industry, Length: 100, dtype: float64

# %%
df["Industry"]= df["Industry"].str.lstrip("...")
df
# Out:
#     Rank                      Name                    Industry  \
# 0      1                   Walmart                      Retail
# 1      2                    Amazon  Retail and cloud computing
# 2      3                ExxonMobil          Petroleum industry
# 3      4                     Apple        Electronics industry
# 4      5        UnitedHealth Group                  Healthcare
# ..   ...                       ...                         ...
# 95    96                  Best Buy                      Retail
# 96    97      Bristol-Myers Squibb     Pharmaceutical industry
# 97    98           United Airlines                     Airline
# 98    99  Thermo Fisher Scientific      Laboratory instruments
# 99   100                  Qualcomm                  Technology
#
#     Revenue (USD millions)  Revenue growth
# 0                   611289           0.067
# 1                   513983           0.094
# 2                   413680           0.448
# ...

# %%
df["Industry"] = df["Industry"].str.rstrip("_")
df
# Out:
#     Rank                      Name                    Industry  \
# 0      1                   Walmart                      Retail
# 1      2                    Amazon  Retail and cloud computing
# 2      3                ExxonMobil          Petroleum industry
# 3      4                     Apple        Electronics industry
# 4      5        UnitedHealth Group                  Healthcare
# ..   ...                       ...                         ...
# 95    96                  Best Buy                      Retail
# 96    97      Bristol-Myers Squibb     Pharmaceutical industry
# 97    98           United Airlines                     Airline
# 98    99  Thermo Fisher Scientific      Laboratory instruments
# 99   100                  Qualcomm                  Technology
#
#     Revenue (USD millions)  Revenue growth
# 0                   611289           0.067
# 1                   513983           0.094
# 2                   413680           0.448
# ...

# %%
df["Industry"] = df["Industry"].str.strip("99")
df
# Out:
#     Rank                      Name                    Industry  \
# 0      1                   Walmart                      Retail
# 1      2                    Amazon  Retail and cloud computing
# 2      3                ExxonMobil          Petroleum industry
# 3      4                     Apple        Electronics industry
# 4      5        UnitedHealth Group                  Healthcare
# ..   ...                       ...                         ...
# 95    96                  Best Buy                      Retail
# 96    97      Bristol-Myers Squibb     Pharmaceutical industry
# 97    98           United Airlines                     Airline
# 98    99  Thermo Fisher Scientific      Laboratory instruments
# 99   100                  Qualcomm                  Technology
#
#     Revenue (USD millions)  Revenue growth
# 0                   611289           0.067
# 1                   513983           0.094
# 2                   413680           0.448
# ...

# %%
df["Industry"].str.strip("123._/")
df
# Out:
#     Rank                      Name                    Industry  \
# 0      1                   Walmart                      Retail
# 1      2                    Amazon  Retail and cloud computing
# 2      3                ExxonMobil          Petroleum industry
# 3      4                     Apple        Electronics industry
# 4      5        UnitedHealth Group                  Healthcare
# ..   ...                       ...                         ...
# 95    96                  Best Buy                      Retail
# 96    97      Bristol-Myers Squibb     Pharmaceutical industry
# 97    98           United Airlines                     Airline
# 98    99  Thermo Fisher Scientific      Laboratory instruments
# 99   100                  Qualcomm                  Technology
#
#     Revenue (USD millions)  Revenue growth
# 0                   611289           0.067
# 1                   513983           0.094
# 2                   413680           0.448
# ...

# %%
 df["Industry"].str.replace('[^a-za-Z0-9]','')
# Out:
# 0                         Retail
# 1     Retail and cloud computing
# 2             Petroleum industry
# 3           Electronics industry
# 4                     Healthcare
#                  ...
# 95                        Retail
# 96       Pharmaceutical industry
# 97                       Airline
# 98        Laboratory instruments
# 99                    Technology
# Name: Industry, Length: 100, dtype: object

# %%
df["Industry"] = df["Industry"].str.replace('[^a-za-Z0-9]','')
df
# Out:
#     Rank                      Name                    Industry  \
# 0      1                   Walmart                      Retail
# 1      2                    Amazon  Retail and cloud computing
# 2      3                ExxonMobil          Petroleum industry
# 3      4                     Apple        Electronics industry
# 4      5        UnitedHealth Group                  Healthcare
# ..   ...                       ...                         ...
# 95    96                  Best Buy                      Retail
# 96    97      Bristol-Myers Squibb     Pharmaceutical industry
# 97    98           United Airlines                     Airline
# 98    99  Thermo Fisher Scientific      Laboratory instruments
# 99   100                  Qualcomm                  Technology
#
#     Revenue (USD millions)  Revenue growth
# 0                   611289           0.067
# 1                   513983           0.094
# 2                   413680           0.448
# ...

# %%
#df["Revenue growth"].apply(lambda x: x[0:3]+'-'+x[3:6]+'-'+x[9:6])

# %%
str(df["Revenue growth"])
# Out:
# '0     0.067\n1     0.094\n2     0.448\n3     0.078\n4     0.127\n      ...  \n95    0.106\n96    0.005\n97    0.825\n98    0.145\n99    0.317\nName: Revenue growth, Length: 100, dtype: float64'

# %%
df["Revenue growth"].apply(lambda x : str(x))
# Out:
# 0     0.067
# 1     0.094
# 2     0.448
# 3     0.078
# 4     0.127
#       ...
# 95    0.106
# 96    0.005
# 97    0.825
# 98    0.145
# 99    0.317
# Name: Revenue growth, Length: 100, dtype: object

# %%
df["Revenue growth"] = df["Revenue growth"].apply(lambda x : str(x))

# %%
df["Revenue growth"].apply(lambda x: x[0:3]+'-'+x[3:6]+'-'+x[9:6])
# Out:
# 0     0.0-67-
# 1     0.0-94-
# 2     0.4-48-
# 3     0.0-78-
# 4     0.1-27-
#        ...
# 95    0.1-06-
# 96    0.0-05-
# 97    0.8-25-
# 98    0.1-45-
# 99    0.3-17-
# Name: Revenue growth, Length: 100, dtype: object

# %%
# removing na and nan in cloumn
df["Revenue growth"].str.replace('nan--','')
df["Revenue growth"].str.replace('Na--','')
df
# Out:
#     Rank                      Name                    Industry  \
# 0      1                   Walmart                      Retail
# 1      2                    Amazon  Retail and cloud computing
# 2      3                ExxonMobil          Petroleum industry
# 3      4                     Apple        Electronics industry
# 4      5        UnitedHealth Group                  Healthcare
# ..   ...                       ...                         ...
# 95    96                  Best Buy                      Retail
# 96    97      Bristol-Myers Squibb     Pharmaceutical industry
# 97    98           United Airlines                     Airline
# 98    99  Thermo Fisher Scientific      Laboratory instruments
# 99   100                  Qualcomm                  Technology
#
#     Revenue (USD millions) Revenue growth
# 0                   611289        0.0-67-
# 1                   513983        0.0-94-
# 2                   413680        0.4-48-
# ...

# %%
# Split column in three more columns if having comma seprater in in values
#df["Industry"].str.split(',',1,expand=True)
#df[["Street_Address","State","Zip_Code"]]=df["Industry"].str.split(' ',1,expand=True)

# %%
# replace yes and no by Y, N in column 
#df["Revenue growth"] = df["Revenue growth"].str.place('Yes','Y')
#df["Revenue growth"] = df["Revenue growth"].str.place('No','N')

# %%
# repalceing value in blank 
#df= df.replace('n/a','')
#df= df.repalce('nan','')

# %%
#remove garbage
df.fillna('')
# Out:
#     Rank                      Name                    Industry  \
# 0      1                   Walmart                      Retail
# 1      2                    Amazon  Retail and cloud computing
# 2      3                ExxonMobil          Petroleum industry
# 3      4                     Apple        Electronics industry
# 4      5        UnitedHealth Group                  Healthcare
# ..   ...                       ...                         ...
# 95    96                  Best Buy                      Retail
# 96    97      Bristol-Myers Squibb     Pharmaceutical industry
# 97    98           United Airlines                     Airline
# 98    99  Thermo Fisher Scientific      Laboratory instruments
# 99   100                  Qualcomm                  Technology
#
#     Revenue (USD millions) Revenue growth
# 0                   611289        0.0-67-
# 1                   513983        0.0-94-
# 2                   413680        0.4-48-
# ...

# %%
# drop value
for x in df.index:
    if df.loc[x,"Revenue growth"]=='Y':
        df.drop(x, inplace=True)
df
# Out:
#     Rank                      Name                    Industry  \
# 0      1                   Walmart                      Retail
# 1      2                    Amazon  Retail and cloud computing
# 2      3                ExxonMobil          Petroleum industry
# 3      4                     Apple        Electronics industry
# 4      5        UnitedHealth Group                  Healthcare
# ..   ...                       ...                         ...
# 95    96                  Best Buy                      Retail
# 96    97      Bristol-Myers Squibb     Pharmaceutical industry
# 97    98           United Airlines                     Airline
# 98    99  Thermo Fisher Scientific      Laboratory instruments
# 99   100                  Qualcomm                  Technology
#
#     Revenue (USD millions) Revenue growth
# 0                   611289        0.0-67-
# 1                   513983        0.0-94-
# 2                   413680        0.4-48-
# ...

# %%
# repalceing
#df["Revenue growth"].str.replace('','N')

# %%
# drop value   
for x in df.index:
    if df.loc[x,"Revenue (USD millions)"] == '':
        df.drop(x, inplace=True)
df
# Out:
#     Rank                      Name                    Industry  \
# 0      1                   Walmart                      Retail
# 1      2                    Amazon  Retail and cloud computing
# 2      3                ExxonMobil          Petroleum industry
# 3      4                     Apple        Electronics industry
# 4      5        UnitedHealth Group                  Healthcare
# ..   ...                       ...                         ...
# 95    96                  Best Buy                      Retail
# 96    97      Bristol-Myers Squibb     Pharmaceutical industry
# 97    98           United Airlines                     Airline
# 98    99  Thermo Fisher Scientific      Laboratory instruments
# 99   100                  Qualcomm                  Technology
#
#     Revenue (USD millions) Revenue growth
# 0                   611289        0.0-67-
# 1                   513983        0.0-94-
# 2                   413680        0.4-48-
# ...

# %%
df= df.reset_index(drop=True)
df
# Out:
#     Rank                      Name                    Industry  \
# 0      1                   Walmart                      Retail
# 1      2                    Amazon  Retail and cloud computing
# 2      3                ExxonMobil          Petroleum industry
# 3      4                     Apple        Electronics industry
# 4      5        UnitedHealth Group                  Healthcare
# ..   ...                       ...                         ...
# 95    96                  Best Buy                      Retail
# 96    97      Bristol-Myers Squibb     Pharmaceutical industry
# 97    98           United Airlines                     Airline
# 98    99  Thermo Fisher Scientific      Laboratory instruments
# 99   100                  Qualcomm                  Technology
#
#     Revenue (USD millions) Revenue growth
# 0                   611289        0.0-67-
# 1                   513983        0.0-94-
# 2                   413680        0.4-48-
# ...

# %%
# drop value and 
for x in df.index:
    if df.loc[x,"Revenue (USD millions)"] == '':
        df.drop(x, inplace=True)
df
#another way to drop null values
df=df.dropna(subset="Revenue (USD millions)", inplace=True)
