# %%
import pandas as pd

# %%
df= pd.read_csv(r"C:\Python file short folder\compineslist.csv")

# %%
df
# Out:
#     Rank                      Name                    Industry  \
# 0      1                   Walmart                      Retail
# 1      2                    Amazon  Retail and cloud computing
# 2      3                ExxonMobil          Petroleum industry
# 3      4                     Apple        Electronics industry
# 4      5        UnitedHealth Group                  Healthcare
# ..   ...                       ...                         ...
# 95    96                  Best Buy                      Retail
# 96    97      Bristol-Myers Squibb     Pharmaceutical industry
# 97    98           United Airlines                     Airline
# 98    99  Thermo Fisher Scientific      Laboratory instruments
# 99   100                  Qualcomm                  Technology
#
#    Revenue (USD millions) Revenue growth  Employees             Headquarters
# 0                 611,289           6.7%  2,100,000    Bentonville, Arkansas
# ...

# %%
df[df['Rank']<=10]
# Out:
#    Rank                  Name                        Industry  \
# 0     1               Walmart                          Retail
# 1     2                Amazon      Retail and cloud computing
# 2     3            ExxonMobil              Petroleum industry
# 3     4                 Apple            Electronics industry
# 4     5    UnitedHealth Group                      Healthcare
# 5     6            CVS Health                      Healthcare
# 6     7    Berkshire Hathaway                    Conglomerate
# 7     8              Alphabet  Technology and cloud computing
# 8     9  McKesson Corporation                          Health
# 9    10   Chevron Corporation              Petroleum industry
#
#   Revenue (USD millions) Revenue growth  Employees               Headquarters
# 0                611,289           6.7%  2,100,000      Bentonville, Arkansas
# 1                513,983           9.4%  1,540,000        Seattle, Washington
# ...

# %%
specific_name = ['Apple','Walmart']
df[df['Name'].isin(specific_name)]
# Out:
#    Rank     Name              Industry Revenue (USD millions) Revenue growth  \
# 0     1  Walmart                Retail                611,289           6.7%
# 3     4    Apple  Electronics industry                394,328           7.8%
#
#    Employees           Headquarters
# 0  2,100,000  Bentonville, Arkansas
# 3    164,000  Cupertino, California

# %%
df[df['Name'].str.contains('Apple')]
# Out:
#    Rank   Name              Industry Revenue (USD millions) Revenue growth  \
# 3     4  Apple  Electronics industry                394,328           7.8%
#
#   Employees           Headquarters
# 3   164,000  Cupertino, California

# %%
df2=df.set_index('Name')
df2
# Out:
#                           Rank                    Industry  \
# Name
# Walmart                      1                      Retail
# Amazon                       2  Retail and cloud computing
# ExxonMobil                   3          Petroleum industry
# Apple                        4        Electronics industry
# UnitedHealth Group           5                  Healthcare
# ...                        ...                         ...
# Best Buy                    96                      Retail
# Bristol-Myers Squibb        97     Pharmaceutical industry
# United Airlines             98                     Airline
# Thermo Fisher Scientific    99      Laboratory instruments
# Qualcomm                   100                  Technology
#
#                          Revenue (USD millions) Revenue growth  Employees  \
# Name
# Walmart                                 611,289           6.7%  2,100,000
# Amazon                                  513,983           9.4%  1,540,000
# ...

# %%
df2.filter(items=['Continent','Industry'],axis=1)
# Out:
#                                             Industry
# Name
# Walmart                                       Retail
# Amazon                    Retail and cloud computing
# ExxonMobil                        Petroleum industry
# Apple                           Electronics industry
# UnitedHealth Group                        Healthcare
# ...                                              ...
# Best Buy                                      Retail
# Bristol-Myers Squibb         Pharmaceutical industry
# United Airlines                              Airline
# Thermo Fisher Scientific      Laboratory instruments
# Qualcomm                                  Technology
#
# [100 rows x 1 columns]

# %%
df2.filter(items=['Amazon'],axis=0)
# Out:
#         Rank                    Industry Revenue (USD millions)  \
# Amazon     2  Retail and cloud computing                513,983
#
#        Revenue growth  Employees         Headquarters
# Amazon           9.4%  1,540,000  Seattle, Washington

# %%
df2.filter(like = 'Amazon',axis=0)
# Out:
#         Rank                    Industry Revenue (USD millions)  \
# Name
# Amazon     2  Retail and cloud computing                513,983
#
#        Revenue growth  Employees         Headquarters
# Name
# Amazon           9.4%  1,540,000  Seattle, Washington

# %%
df2.loc['Amazon']
# Out:
# Rank                                               2
# Industry                  Retail and cloud computing
# Revenue (USD millions)                       513,983
# Revenue growth                                  9.4%
# Employees                                  1,540,000
# Headquarters                     Seattle, Washington
# Name: Amazon, dtype: object

# %%
df2.iloc[1]
# Out:
# Rank                                               2
# Industry                  Retail and cloud computing
# Revenue (USD millions)                       513,983
# Revenue growth                                  9.4%
# Employees                                  1,540,000
# Headquarters                     Seattle, Washington
# Name: Amazon, dtype: object

# %%
df
# Out:
#     Rank                      Name                    Industry  \
# 0      1                   Walmart                      Retail
# 1      2                    Amazon  Retail and cloud computing
# 2      3                ExxonMobil          Petroleum industry
# 3      4                     Apple        Electronics industry
# 4      5        UnitedHealth Group                  Healthcare
# ..   ...                       ...                         ...
# 95    96                  Best Buy                      Retail
# 96    97      Bristol-Myers Squibb     Pharmaceutical industry
# 97    98           United Airlines                     Airline
# 98    99  Thermo Fisher Scientific      Laboratory instruments
# 99   100                  Qualcomm                  Technology
#
#    Revenue (USD millions) Revenue growth  Employees             Headquarters
# 0                 611,289           6.7%  2,100,000    Bentonville, Arkansas
# ...

# %%
df[df['Rank']< 10].sort_values(by='Rank',ascending=True)
# Out:
#    Rank                  Name                        Industry  \
# 0     1               Walmart                          Retail
# 1     2                Amazon      Retail and cloud computing
# 2     3            ExxonMobil              Petroleum industry
# 3     4                 Apple            Electronics industry
# 4     5    UnitedHealth Group                      Healthcare
# 5     6            CVS Health                      Healthcare
# 6     7    Berkshire Hathaway                    Conglomerate
# 7     8              Alphabet  Technology and cloud computing
# 8     9  McKesson Corporation                          Health
#
#   Revenue (USD millions) Revenue growth  Employees               Headquarters
# 0                611,289           6.7%  2,100,000      Bentonville, Arkansas
# 1                513,983           9.4%  1,540,000        Seattle, Washington
# 2                413,680          44.8%     62,000              Spring, Texas
# ...

# %%
df[df['Rank']< 10].sort_values(by=['Rank','Name'],ascending=True)
# Out:
#    Rank                  Name                        Industry  \
# 0     1               Walmart                          Retail
# 1     2                Amazon      Retail and cloud computing
# 2     3            ExxonMobil              Petroleum industry
# 3     4                 Apple            Electronics industry
# 4     5    UnitedHealth Group                      Healthcare
# 5     6            CVS Health                      Healthcare
# 6     7    Berkshire Hathaway                    Conglomerate
# 7     8              Alphabet  Technology and cloud computing
# 8     9  McKesson Corporation                          Health
#
#   Revenue (USD millions) Revenue growth  Employees               Headquarters
# 0                611,289           6.7%  2,100,000      Bentonville, Arkansas
# 1                513,983           9.4%  1,540,000        Seattle, Washington
# 2                413,680          44.8%     62,000              Spring, Texas
# ...

# %%
df[df['Rank']< 10].sort_values(by=['Rank','Name'],ascending=[True,False])
# Out:
#    Rank                  Name                        Industry  \
# 0     1               Walmart                          Retail
# 1     2                Amazon      Retail and cloud computing
# 2     3            ExxonMobil              Petroleum industry
# 3     4                 Apple            Electronics industry
# 4     5    UnitedHealth Group                      Healthcare
# 5     6            CVS Health                      Healthcare
# 6     7    Berkshire Hathaway                    Conglomerate
# 7     8              Alphabet  Technology and cloud computing
# 8     9  McKesson Corporation                          Health
#
#   Revenue (USD millions) Revenue growth  Employees               Headquarters
# 0                611,289           6.7%  2,100,000      Bentonville, Arkansas
# 1                513,983           9.4%  1,540,000        Seattle, Washington
# 2                413,680          44.8%     62,000              Spring, Texas
# ...
