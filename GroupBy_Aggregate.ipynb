# %%
import pandas as pd

# %%
df = pd.read_csv(r"C:\Python file short folder\compineslist.csv")
df
# Out:
#     Rank                      Name                    Industry  \
# 0      1                   Walmart                      Retail
# 1      2                    Amazon  Retail and cloud computing
# 2      3                ExxonMobil          Petroleum industry
# 3      4                     Apple        Electronics industry
# 4      5        UnitedHealth Group                  Healthcare
# ..   ...                       ...                         ...
# 95    96                  Best Buy                      Retail
# 96    97      Bristol-Myers Squibb     Pharmaceutical industry
# 97    98           United Airlines                     Airline
# 98    99  Thermo Fisher Scientific      Laboratory instruments
# 99   100                  Qualcomm                  Technology
#
#     Revenue (USD millions)  Revenue growth   Employees
# 0                 611289.0            0.07  2100000.00
# 1                 513983.0            0.09  1540000.00
# ...

# %%
group_by_frame = df.groupby('Industry')
#group_by_frame.mean()

# %%
#df.groupby('Industry').mean()

# %%
df.groupby('Industry').count()
# Out:
#                                     Rank  Name  Revenue (USD millions)  \
# Industry
# Aerospace and defense                  2     2                       2
# Agriculture cooperative                1     1                       1
# Agriculture manufacturing              1     1                       1
# Airline                                3     3                       3
# Apparel                                1     1                       1
# Automotive and energy                  1     1                       1
# Automotive industry                    2     2                       2
# Beverage                               1     1                       1
# Chemical industry                      1     1                       1
# Conglomerate                           3     3                       3
# Conglomerate and telecomunications     1     1                       1
# Consumer products manufacturing        1     1                       1
# ...

# %%
#df.groupby('Industry').mean()

# %%
df.groupby('Industry').min()
# Out:
#                                     Rank                          Name  \
# Industry
# Aerospace and defense                 60                        Boeing
# Agriculture cooperative               92                           CHS
# Agriculture manufacturing             83                    John Deere
# Airline                               87             American Airlines
# Apparel                               95                          Nike
# Automotive and energy                 50                         Tesla
# Automotive industry                   19            Ford Motor Company
# Beverage                              46                       PepsiCo
# Chemical industry                     77          Dow Chemical Company
# Conglomerate                           7            Berkshire Hathaway
# Conglomerate and telecomunications    30                          AT&T
# Consumer products manufacturing       51              Procter & Gamble
# ...

# %%
df.groupby('Industry').max()
# Out:
#                                     Rank                                 Name  \
# Industry
# Aerospace and defense                 62                      Lockheed Martin
# Agriculture cooperative               92                                  CHS
# Agriculture manufacturing             83                           John Deere
# Airline                               98                      United Airlines
# Apparel                               95                                 Nike
# Automotive and energy                 50                                Tesla
# Automotive industry                   21                       General Motors
# Beverage                              46                              PepsiCo
# Chemical industry                     77                 Dow Chemical Company
# Conglomerate                          59                      RTX Corporation
# Conglomerate and telecomunications    30                                 AT&T
# ...

# %%
df.groupby('Industry').sum()
# Out:
#                                     Rank  \
# Industry
# Aerospace and defense                122
# Agriculture cooperative               92
# Agriculture manufacturing             83
# Airline                              276
# Apparel                               95
# Automotive and energy                 50
# Automotive industry                   40
# Beverage                              46
# Chemical industry                     77
# Conglomerate                         120
# Conglomerate and telecomunications    30
# Consumer products manufacturing       51
# Electronics industry                   4
# Financial                            164
# Financial services                    23
# Financials                           536
# Food industry                         93
# Food processing                      175
# Food service                          57
# Health                                 9
# Health insurance                      57
# ...

# %%
df.groupby('Industry').agg({'Revenue growth':['min','max','sum']})
# Out:
#                                    Revenue growth
#                                               min   max   sum
# Industry
# Aerospace and defense                        0.02  0.07  0.09
# Agriculture cooperative                      0.24  0.24  0.24
# Agriculture manufacturing                    0.19  0.19  0.19
# Airline                                      0.64  0.83  2.16
# Apparel                                      0.05  0.05  0.05
# Automotive and energy                        0.51  0.51  0.51
# Automotive industry                          0.16  0.23  0.39
# Beverage                                     0.09  0.09  0.09
# Chemical industry                            0.04  0.04  0.04
# Conglomerate                                 0.03  0.09  0.16
# Conglomerate and telecomunications           0.29  0.29  0.29
# Consumer products manufacturing              0.05  0.05  0.05
# Electronics industry                         0.08  0.08  0.08
# ...

# %%
df.groupby(['Industry','Name']).agg({'Revenue growth':['min','max','sum']})
# Out:
#                                                  Revenue growth
#                                                             min   max   sum
# Industry                  Name
# Aerospace and defense     Boeing                           0.07  0.07  0.07
#                           Lockheed Martin                  0.02  0.02  0.02
# Agriculture cooperative   CHS                              0.24  0.24  0.24
# Agriculture manufacturing John Deere                       0.19  0.19  0.19
# Airline                   American Airlines                0.64  0.64  0.64
# ...                                                         ...   ...   ...
# Telecommunications        Charter Communications           0.05  0.05  0.05
#                           Comcast                          0.04  0.04  0.04
#                           Verizon Communications           0.02  0.02  0.02
# Transportation            FedEx                            0.11  0.11  0.11
# ...

# %%
df.groupby('Industry').describe()
# Out:
#                                     Rank                                     \
#                                    count       mean        std   min    25%
# Industry
# Aerospace and defense                2.0  61.000000   1.414214  60.0  60.50
# Agriculture cooperative              1.0  92.000000        NaN  92.0  92.00
# Agriculture manufacturing            1.0  83.000000        NaN  83.0  83.00
# Airline                              3.0  92.000000   5.567764  87.0  89.00
# Apparel                              1.0  95.000000        NaN  95.0  95.00
# Automotive and energy                1.0  50.000000        NaN  50.0  50.00
# Automotive industry                  2.0  20.000000   1.414214  19.0  19.50
# Beverage                             1.0  46.000000        NaN  46.0  46.00
# Chemical industry                    1.0  77.000000        NaN  77.0  77.00
# Conglomerate                         3.0  40.000000  28.687977   7.0  30.50
# ...
