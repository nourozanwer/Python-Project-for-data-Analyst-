# %%
EDA in Pandas

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv(r'C:\Python file short folder\compineslist.csv')
df
# Out:
#     Rank                      Name                    Industry  \
# 0      1                   Walmart                      Retail
# 1      2                    Amazon  Retail and cloud computing
# 2      3                ExxonMobil          Petroleum industry
# 3      4                     Apple        Electronics industry
# 4      5        UnitedHealth Group                  Healthcare
# ..   ...                       ...                         ...
# 95    96                  Best Buy                      Retail
# 96    97      Bristol-Myers Squibb     Pharmaceutical industry
# 97    98           United Airlines                     Airline
# 98    99  Thermo Fisher Scientific      Laboratory instruments
# 99   100                  Qualcomm                  Technology
#
#     Revenue (USD millions)  Revenue growth   Employees
# 0                611289.00            0.07  2100000.00
# 1                513983.00            0.09  1540000.00
# ...

# %%
pd.set_option('display.float_format', lambda x: '%.2f'% x)
df
# Out:
#     Rank                      Name                    Industry  \
# 0      1                   Walmart                      Retail
# 1      2                    Amazon  Retail and cloud computing
# 2      3                ExxonMobil          Petroleum industry
# 3      4                     Apple        Electronics industry
# 4      5        UnitedHealth Group                  Healthcare
# ..   ...                       ...                         ...
# 95    96                  Best Buy                      Retail
# 96    97      Bristol-Myers Squibb     Pharmaceutical industry
# 97    98           United Airlines                     Airline
# 98    99  Thermo Fisher Scientific      Laboratory instruments
# 99   100                  Qualcomm                  Technology
#
#     Revenue (USD millions)  Revenue growth   Employees
# 0                611289.00            0.07  2100000.00
# 1                513983.00            0.09  1540000.00
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 6 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Rank                    100 non-null    int64
#  1   Name                    100 non-null    object
#  2   Industry                100 non-null    object
#  3   Revenue (USD millions)  100 non-null    float64
#  4   Revenue growth          100 non-null    float64
#  5   Employees               100 non-null    object
# dtypes: float64(2), int64(1), object(3)
# memory usage: 4.8+ KB

# %%
df.describe()
# Out:
#         Rank  Revenue (USD millions)  Revenue growth
# count 100.00                  100.00          100.00
# mean   50.50               117566.46            0.20
# std    29.01               100915.11            0.21
# min     1.00                44200.00            0.01
# 25%    25.75                57876.00            0.04
# 50%    50.50                80824.50            0.12
# 75%    75.25               138763.00            0.23
# max   100.00               611289.00            0.97

# %%
df.isnull().sum()
# Out:
# Rank                      0
# Name                      0
# Industry                  0
# Revenue (USD millions)    0
# Revenue growth            0
# Employees                 0
# dtype: int64

# %%
#df.unique()

# %%
df.sort_values(by="Name",ascending=False).head(10)
# Out:
#     Rank                          Name                          Industry  \
# 71    72           World Fuel Services  Petroleum industry and logistics
# 46    47                   Wells Fargo                        Financials
# 0      1                       Walmart                            Retail
# 26    27      Walgreens Boots Alliance           Pharmaceutical industry
# 25    26        Verizon Communications                Telecommunications
# 17    18                 Valero Energy                Petroleum industry
# 4      5            UnitedHealth Group                        Healthcare
# 51    52  United States Postal Service                         Logistics
# 36    37         United Parcel Service                    Transportation
# 97    98               United Airlines                           Airline
#
#     Revenue (USD millions)  Revenue growth   Employees
# 71                59043.00            0.88     5214.00
# ...

# %%
#sns.heatmap(df.corr(),annot=True)
#plt.rcParams['figure.figsize']=(20,7)
#plt.show()

# %%
df.groupby('Name')

# %%
#df.groupby('Name').mean().sort_values(by="Name", ascending=False)

# %%
df2= df[df['Industry'].str.contains('Healthcare')]
df2
# Out:
#     Rank                Name    Industry  Revenue (USD millions)  \
# 4      5  UnitedHealth Group  Healthcare               324162.00
# 5      6          CVS Health  Healthcare               322467.00
# 13    14     Cardinal Health  Healthcare               181364.00
# 21    22     Elevance Health  Healthcare               156595.00
# 24    25             Centene  Healthcare               144547.00
# 67    68      HCA Healthcare  Healthcare                60233.00
#
#     Revenue growth  Employees
# 4             0.13  400000.00
# 5             0.10  259500.00
# 13            0.12   46035.00
# 21            0.13  102200.00
# 24            0.15   74300.00
# 67            0.03  250500.00

# %%
df2.transpose()
df2.plot()
# Out:
# <Axes: >

# %%
#df.columns()

# %%
#df.groupby('Name')[[pasthere all column name]].mean().sort_values(by="Name", ascending=False)

# %%
df.boxplot(figsize=(5,5))
# Out:
# <Axes: >

# %%
df.dtypes
# Out:
# Rank                        int64
# Name                       object
# Industry                   object
# Revenue (USD millions)    float64
# Revenue growth            float64
# Employees                  object
# dtype: object

# %%
df.select_dtypes(include='object')
# Out:
#                         Name                    Industry   Employees
# 0                    Walmart                      Retail  2100000.00
# 1                     Amazon  Retail and cloud computing  1540000.00
# 2                 ExxonMobil          Petroleum industry    62000.00
# 3                      Apple        Electronics industry   164000.00
# 4         UnitedHealth Group                  Healthcare   400000.00
# ..                       ...                         ...         ...
# 95                  Best Buy                      Retail    71100.00
# 96      Bristol-Myers Squibb     Pharmaceutical industry    34300.00
# 97           United Airlines                     Airline    92795.00
# 98  Thermo Fisher Scientific      Laboratory instruments   130000.00
# 99                  Qualcomm                  Technology    51000.00
#
# [100 rows x 3 columns]
